# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from fastai import *
from fastai.vision import *
from fastai.metrics import error_rate, FBeta
from fastai.callbacks import *

# %%
data = ImageDataBunch.from_folder(path='/content/drive/MyDrive/FastAI/Meat New Dataset BW TTV', 
                                  train = 'train', 
                                  valid = 'val',
                                  size =64,
                                  bs=64)
#dls = ImageDataLoaders.from_folder(path='/content/drive/My Drive/Meat_Images/TrainTest',
                                   #valid_pct=0.2)

# %%
data_new = ImageDataBunch.from_folder(path='/content/drive/MyDrive/FastAI/Meat New Dataset BW TTV', 
                                  train = 'train', 
                                  valid = 'test',
                                  size =64,
                                  bs=64)

# %%
data.classes
# Out:
# ['20001', '20002', '20003', '20004', '20010']

# %%
data.show_batch(rows = 4, figsize=(10,10))

# %%
model= cnn_learner(data,models.resnet34,metrics=[accuracy,
               Precision(average='micro'),
               Recall(average='micro'),
               FBeta(average='micro')], callback_fns= ShowGraph)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# ...

# %%
#model.unfreeze() 
#model.fit_one_cycle(3, max_lr=slice(1e-03, 1e-02))
model.fit_one_cycle(50, callbacks =[callbacks.SaveModelCallback(model, every='epoch', monitor = 'valid_loss')])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f_beta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.159523</td>
#       <td>0.521808</td>
#       <td>0.821044</td>
#       <td>0.821044</td>
#       <td>0.821044</td>
#       <td>0.821044</td>
#       <td>16:50</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.761147</td>
#       <td>0.418305</td>
#       <td>0.841756</td>
#       <td>0.841756</td>
#       <td>0.841756</td>
#       <td>0.841756</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.599574</td>
#       <td>0.382611</td>
#       <td>0.852527</td>
#       <td>0.852527</td>
#       <td>0.852527</td>
#       <td>0.852527</td>
#       <td>00:15</td>
#     </tr>
# ...

# %%
model_new= cnn_learner(data_new,models.resnet34,metrics=[accuracy,
               Precision(average='micro'),
               Recall(average='micro'),
               FBeta(average='micro')], callback_fns= ShowGraph)

# %%
model_new.load('/content/drive/MyDrive/FastAI/Meat New Dataset BW TTV/models/bestmodel_48')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (5656 items)
# x: ImageList
# Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64)
# y: CategoryList
# 20001,20001,20001,20001,20001
# Path: /content/drive/MyDrive/FastAI/Meat New Dataset BW TTV;
#
# Valid: LabelList (1215 items)
# x: ImageList
# Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64)
# y: CategoryList
# 20010,20010,20010,20010,20010
# Path: /content/drive/MyDrive/FastAI/Meat New Dataset BW TTV;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
# ...

# %%
model_new.validate(data_new.valid_dl)
# Out:
# [0.6079592, tensor(0.9053), tensor(0.9053), tensor(0.9053), tensor(0.9053)]

# %%
model_30= cnn_learner(data,models.resnet34,metrics=[accuracy,
               Precision(average='micro'),
               Recall(average='micro'),
               FBeta(average='micro')], callback_fns= ShowGraph)

# %%
#model.unfreeze() 
#model.fit_one_cycle(3, max_lr=slice(1e-03, 1e-02))
model_30.fit_one_cycle(30, callbacks =[callbacks.SaveModelCallback(model, every='epoch', monitor = 'valid_loss')])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f_beta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.088802</td>
#       <td>0.461588</td>
#       <td>0.832643</td>
#       <td>0.832643</td>
#       <td>0.832643</td>
#       <td>0.832643</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.691413</td>
#       <td>0.369742</td>
#       <td>0.871582</td>
#       <td>0.871582</td>
#       <td>0.871582</td>
#       <td>0.871582</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.530726</td>
#       <td>0.365567</td>
#       <td>0.863297</td>
#       <td>0.863297</td>
#       <td>0.863297</td>
#       <td>0.863297</td>
#       <td>00:15</td>
#     </tr>
# ...

# %%
model_new_30= cnn_learner(data_new,models.resnet34,metrics=[accuracy,
               Precision(average='micro'),
               Recall(average='micro'),
               FBeta(average='micro')], callback_fns= ShowGraph)

# %%
model_new_30.load('/content/drive/MyDrive/FastAI/Meat New Dataset BW TTV/models/bestmodel_27')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (5656 items)
# x: ImageList
# Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64)
# y: CategoryList
# 20001,20001,20001,20001,20001
# Path: /content/drive/MyDrive/FastAI/Meat New Dataset BW TTV;
#
# Valid: LabelList (1215 items)
# x: ImageList
# Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64)
# y: CategoryList
# 20010,20010,20010,20010,20010
# Path: /content/drive/MyDrive/FastAI/Meat New Dataset BW TTV;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
# ...

# %%
model_new_30.validate(data_new.valid_dl)
# Out:
# [0.6012101, tensor(0.9086), tensor(0.9086), tensor(0.9086), tensor(0.9086)]

# %%
model_25= cnn_learner(data,models.resnet34,metrics=[accuracy,
               Precision(average='micro'),
               Recall(average='micro'),
               FBeta(average='micro')], callback_fns= ShowGraph)

# %%
#model.unfreeze() 
#model.fit_one_cycle(3, max_lr=slice(1e-03, 1e-02))
model_25.fit_one_cycle(25, callbacks =[callbacks.SaveModelCallback(model, every='epoch', monitor = 'valid_loss')])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f_beta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.081860</td>
#       <td>0.457358</td>
#       <td>0.848384</td>
#       <td>0.848384</td>
#       <td>0.848384</td>
#       <td>0.848384</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.691845</td>
#       <td>0.378905</td>
#       <td>0.868268</td>
#       <td>0.868268</td>
#       <td>0.868268</td>
#       <td>0.868268</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.536929</td>
#       <td>0.354383</td>
#       <td>0.875725</td>
#       <td>0.875725</td>
#       <td>0.875725</td>
#       <td>0.875725</td>
#       <td>00:15</td>
#     </tr>
# ...

# %%
model_new_25= cnn_learner(data_new,models.resnet34,metrics=[accuracy,
               Precision(average='micro'),
               Recall(average='micro'),
               FBeta(average='micro')], callback_fns= ShowGraph)

# %%
model_new_25.load('/content/drive/MyDrive/FastAI/Meat New Dataset BW TTV/models/bestmodel_24')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (5656 items)
# x: ImageList
# Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64)
# y: CategoryList
# 20001,20001,20001,20001,20001
# Path: /content/drive/MyDrive/FastAI/Meat New Dataset BW TTV;
#
# Valid: LabelList (1215 items)
# x: ImageList
# Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64)
# y: CategoryList
# 20010,20010,20010,20010,20010
# Path: /content/drive/MyDrive/FastAI/Meat New Dataset BW TTV;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
# ...

# %%
model_new_25.validate(data_new.valid_dl)
# Out:
# [0.6012101, tensor(0.9086), tensor(0.9086), tensor(0.9086), tensor(0.9086)]

# %%
model_20= cnn_learner(data,models.resnet34,metrics=[accuracy,
               Precision(average='micro'),
               Recall(average='micro'),
               FBeta(average='micro')], callback_fns= ShowGraph)

# %%
#model.unfreeze() 
#model.fit_one_cycle(3, max_lr=slice(1e-03, 1e-02))
model_20.fit_one_cycle(20, callbacks =[callbacks.SaveModelCallback(model, every='epoch', monitor = 'valid_loss')])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f_beta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.049226</td>
#       <td>0.470917</td>
#       <td>0.842585</td>
#       <td>0.842585</td>
#       <td>0.842585</td>
#       <td>0.842585</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.651113</td>
#       <td>0.392661</td>
#       <td>0.864126</td>
#       <td>0.864126</td>
#       <td>0.864126</td>
#       <td>0.864126</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.529911</td>
#       <td>0.377887</td>
#       <td>0.868268</td>
#       <td>0.868268</td>
#       <td>0.868268</td>
#       <td>0.868268</td>
#       <td>00:16</td>
#     </tr>
# ...

# %%
model_new_20= cnn_learner(data_new,models.resnet34,metrics=[accuracy,
               Precision(average='micro'),
               Recall(average='micro'),
               FBeta(average='micro')], callback_fns= ShowGraph)

# %%
model_new_20.load('/content/drive/MyDrive/FastAI/Meat New Dataset BW TTV/models/bestmodel_18')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (5656 items)
# x: ImageList
# Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64)
# y: CategoryList
# 20001,20001,20001,20001,20001
# Path: /content/drive/MyDrive/FastAI/Meat New Dataset BW TTV;
#
# Valid: LabelList (1215 items)
# x: ImageList
# Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64)
# y: CategoryList
# 20010,20010,20010,20010,20010
# Path: /content/drive/MyDrive/FastAI/Meat New Dataset BW TTV;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
# ...

# %%
model_new_20.validate(data_new.valid_dl)
# Out:
# [0.6012101, tensor(0.9086), tensor(0.9086), tensor(0.9086), tensor(0.9086)]

# %%
model_10= cnn_learner(data,models.resnet34,metrics=[accuracy,
               Precision(average='micro'),
               Recall(average='micro'),
               FBeta(average='micro')], callback_fns= ShowGraph)

# %%
#model.unfreeze() 
#model.fit_one_cycle(3, max_lr=slice(1e-03, 1e-02))
model_10.fit_one_cycle(10, callbacks =[callbacks.SaveModelCallback(model, every='epoch', monitor = 'valid_loss')])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f_beta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.001401</td>
#       <td>0.414367</td>
#       <td>0.850041</td>
#       <td>0.850041</td>
#       <td>0.850041</td>
#       <td>0.850041</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.620336</td>
#       <td>0.344420</td>
#       <td>0.866611</td>
#       <td>0.866611</td>
#       <td>0.866611</td>
#       <td>0.866611</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.472944</td>
#       <td>0.333436</td>
#       <td>0.888152</td>
#       <td>0.888152</td>
#       <td>0.888152</td>
#       <td>0.888152</td>
#       <td>00:15</td>
#     </tr>
# ...

# %%
model_new_10= cnn_learner(data_new,models.resnet34,metrics=[accuracy,
               Precision(average='micro'),
               Recall(average='micro'),
               FBeta(average='micro')], callback_fns= ShowGraph)

# %%
model_new_10.load('/content/drive/MyDrive/FastAI/Meat New Dataset BW TTV/models/bestmodel_9')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (5656 items)
# x: ImageList
# Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64)
# y: CategoryList
# 20001,20001,20001,20001,20001
# Path: /content/drive/MyDrive/FastAI/Meat New Dataset BW TTV;
#
# Valid: LabelList (1215 items)
# x: ImageList
# Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64)
# y: CategoryList
# 20010,20010,20010,20010,20010
# Path: /content/drive/MyDrive/FastAI/Meat New Dataset BW TTV;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
# ...

# %%
model_new_10.validate(data_new.valid_dl)
# Out:
# [0.6012101, tensor(0.9086), tensor(0.9086), tensor(0.9086), tensor(0.9086)]
